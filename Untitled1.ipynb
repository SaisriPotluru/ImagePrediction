# %%
from IPython.display import Image

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 7s 0us/step

# %%
def classifyimage(img_path):
    display(Image(filename=img_path))
    
    img = image.load_img(img_path, target_size=(224, 224))

    y = image.img_to_array(img)
    y = np.expand_dims(y, axis=0)
    y = preprocess_input(y)

    preds = model.predict(y)
    print('Predicted:', decode_predictions(preds, top=3)[0])

# %%
classifyimage('Lion.jpg')
# Out:
# Predicted: [('n02130308', 'cheetah', 0.590493), ('n02437312', 'Arabian_camel', 0.2252068), ('n02129165', 'lion', 0.13580677)]

# %%
classifyimage('firetruck.jpg')
# Out:
# Predicted: [('n03345487', 'fire_engine', 0.9478983), ('n04461696', 'tow_truck', 0.030561874), ('n03594945', 'jeep', 0.004242818)]

# %%
classifyimage('Laptop.jpg')
# Out:
# Predicted: [('n03180011', 'desktop_computer', 0.571382), ('n03782006', 'monitor', 0.16426368), ('n03452741', 'grand_piano', 0.107921325)]
